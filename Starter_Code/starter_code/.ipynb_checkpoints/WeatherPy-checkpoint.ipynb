# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
print(cities)
# Out:
# Number of cities in the list: 597
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q="
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url + city.replace(" ","&")).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | lebu
# Processing Record 3 of Set 1 | ouadda
# Processing Record 4 of Set 1 | waipawa
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | barrow
# Processing Record 8 of Set 1 | atakpame
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | vila franca do campo
# Processing Record 15 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | powell river
# Processing Record 18 of Set 1 | biak
# Processing Record 19 of Set 1 | arraial do cabo
# Processing Record 20 of Set 1 | souillac
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          526
# Lat           526
# Lng           526
# Max Temp      526
# Humidity      526
# Cloudiness    526
# Wind Speed    526
# Country       526
# Date          526
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   hermanus -34.4187   19.2345     21.92        77         100        5.25
# 1       lebu -37.6167  -73.6500     17.73        65           0        6.99
# 2     ouadda   8.0777   22.4007     37.43         7           1        3.40
# 3    waipawa -41.4122  175.5153     13.47        83           4        2.61
# 4  busselton -33.6500  115.3333     18.22        83           0        6.85
#
#   Country        Date
# 0      ZA  1675778712
# 1      CL  1675778715
# 2      CF  1675778718
# 3      NZ  1675778719
# 4      AU  1675778721

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         hermanus -34.4187   19.2345     21.92        77         100
# 1             lebu -37.6167  -73.6500     17.73        65           0
# 2           ouadda   8.0777   22.4007     37.43         7           1
# 3          waipawa -41.4122  175.5153     13.47        83           4
# 4        busselton -33.6500  115.3333     18.22        83           0
#
#          Wind Speed Country        Date
# City_ID
# 0              5.25      ZA  1675778712
# 1              6.99      CL  1675778715
# 2              3.40      CF  1675778718
# 3              2.61      NZ  1675778719
# 4              6.85      AU  1675778721

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], color='b')
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.title("latitude vs. temperature")
# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], color='g')
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("latitude vs. humidity")

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], color='c')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("latitude vs. cloudiness")

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], color='m')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("latitude vs. wind Speed")

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def function(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_value = x_values * slope + intercept
    linepl = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    print(linepl)
    print(f"The r-value is: {rvalue**2}")
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_value, "r-")
    plt.annotate(linepl,(20,15),fontsize=15,color="blue")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
nor_hem_df = (city_data_df.loc[city_data_df['Lat'] >= 0])

# Display sample data
nor_hem_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2              ouadda   8.0777   22.4007     37.43         7           1
# 5        punta arenas   8.9897  125.3400     22.84        91         100
# 6              barrow  71.2906 -156.7887    -21.99        77         100
# 7            atakpame   7.5333    1.1333     35.60        28          97
# 10       puerto ayora  36.5939   -6.2330     17.56        60          20
#
#          Wind Speed Country        Date
# City_ID
# 2              3.40      CF  1675778718
# 5              2.97      PH  1675778723
# 6              2.57      US  1675778656
# 7              2.96      TG  1675778725
# 10             5.14      ES  1675778644

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
south_hem_df = (city_data_df.loc[city_data_df['Lat'] < 0])

# Display sample data
south_hem_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         hermanus -34.4187   19.2345     21.92        77         100
# 1             lebu -37.6167  -73.6500     17.73        65           0
# 3          waipawa -41.4122  175.5153     13.47        83           4
# 4        busselton -33.6500  115.3333     18.22        83           0
# 8          ushuaia -54.8000  -68.3000      9.81        62          40
#
#          Wind Speed Country        Date
# City_ID
# 0              5.25      ZA  1675778712
# 1              6.99      CL  1675778715
# 3              2.61      NZ  1675778719
# 4              6.85      AU  1675778721
# 8              6.69      AR  1675778581

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

x_values = nor_hem_df['Lat']
y_values = nor_hem_df['Max Temp']
plt.figure(figsize=(5,5))
plt.scatter(x_values,y_values)
plt.plot(function(x_values, y_values))
plt.show()
# Out:
# y = -0.85x + 38.12
# The r-value is: 0.7616940711200525
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15696\168785745.py in <module>
#       5 plt.figure(figsize=(5,5))
#       6 plt.scatter(x_values,y_values)
# ----> 7 plt.plot(function(x_values, y_values))
#       8 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
# ...

# %%
# Linear regression on Southern Hemisphere
x_values = south_hem_df['Lat']
y_values = south_hem_df['Max Temp']
plt.figure(figsize=(5,5))
plt.scatter(x_values,y_values)
plt.plot(function(x_values, y_values))
plt.show()
# Out:
# y = 0.22x + 28.96
# The r-value is: 0.33504897073247125
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15696\1869362755.py in <module>
#       4 plt.figure(figsize=(5,5))
#       5 plt.scatter(x_values,y_values)
# ----> 6 plt.plot(function(x_values, y_values))
#       7 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
# ...

# %% [markdown]
# **Discussion about the linear relationship:** As Latitude increases toward the equator temperature also increases relfection a positive correletion.  Furthermore as latitude increases past the equator temperture decreases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = nor_hem_df['Lat']
y_values = nor_hem_df['Humidity']
plt.figure(figsize=(5,5))
plt.scatter(x_values,y_values)
plt.plot(function(x_values, y_values))
plt.show()
# Out:
# y = 0.68x + 43.53
# The r-value is: 0.263224634723106
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15696\2387170589.py in <module>
#       4 plt.figure(figsize=(5,5))
#       5 plt.scatter(x_values,y_values)
# ----> 6 plt.plot(function(x_values, y_values))
#       7 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
# ...

# %%
# Southern Hemisphere
x_values = south_hem_df['Lat']
y_values = south_hem_df['Humidity']
plt.figure(figsize=(5,5))
plt.scatter(x_values,y_values)
plt.plot(function(x_values, y_values))
plt.show()
# Out:
# y = 0.3x + 75.52
# The r-value is: 0.04559463022276805
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15696\3557558124.py in <module>
#       4 plt.figure(figsize=(5,5))
#       5 plt.scatter(x_values,y_values)
# ----> 6 plt.plot(function(x_values, y_values))
#       7 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
# ...

# %% [markdown]
# **Discussion about the linear relationship:** There isn't much relationship between latitude and cloudiness within the southern
# hemisphere. Within the north hemisphere as latitude increases cloudiness increases too.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = nor_hem_df['Lat']
y_values = nor_hem_df['Cloudiness']
plt.figure(figsize=(5,5))
plt.scatter(x_values,y_values)
plt.plot(function(x_values, y_values))
plt.show()
# Out:
# y = 0.38x + 47.66
# The r-value is: 0.037293855717198406
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15696\3077353416.py in <module>
#       4 plt.figure(figsize=(5,5))
#       5 plt.scatter(x_values,y_values)
# ----> 6 plt.plot(function(x_values, y_values))
#       7 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
# ...

# %%
# Southern Hemisphere
x_values = south_hem_df['Lat']
y_values = south_hem_df['Cloudiness']
plt.figure(figsize=(5,5))
plt.scatter(x_values,y_values)
plt.plot(function(x_values, y_values))


plt.show()
# Out:
# y = 1.4x + 93.15
# The r-value is: 0.24802905664025984
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15696\3286791921.py in <module>
#       4 plt.figure(figsize=(5,5))
#       5 plt.scatter(x_values,y_values)
# ----> 6 plt.plot(function(x_values, y_values))
#       7
#       8
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
# ...

# %% [markdown]
# **Discussion about the linear relationship:** There is postive relationship between cloudiness and latitude, however there are a lot of outliers.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = nor_hem_df['Lat']
y_values = nor_hem_df['Wind Speed']
plt.figure(figsize=(5,5))
plt.scatter(x_values,y_values)
plt.plot(function(x_values, y_values))
plt.show()
# Out:
# y = 0.01x + 3.37
# The r-value is: 0.00691770763260482
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15696\1089932518.py in <module>
#       4 plt.figure(figsize=(5,5))
#       5 plt.scatter(x_values,y_values)
# ----> 6 plt.plot(function(x_values, y_values))
#       7 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
# ...

# %%
# Southern Hemisphere
x_values = south_hem_df['Lat']
y_values = south_hem_df['Wind Speed']
plt.figure(figsize=(5,5))
plt.scatter(x_values,y_values)
plt.plot(function(x_values, y_values))
plt.show()
# Out:
# y = -0.03x + 3.13
# The r-value is: 0.03098164725829915
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15696\3185083504.py in <module>
#       4 plt.figure(figsize=(5,5))
#       5 plt.scatter(x_values,y_values)
# ----> 6 plt.plot(function(x_values, y_values))
#       7 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
# ...

# %% [markdown]
# **Discussion about the linear relationship:** There isn't a significant relationship between latitude and windspeed.
